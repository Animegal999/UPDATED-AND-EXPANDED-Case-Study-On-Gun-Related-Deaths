# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2020 <- read.csv("/content/guns_2020.csv", header = TRUE, sep = ",")
View(gunDeathsData_2020)
# Out:
#       year month intent     police sex age race
# 1     2020 1     Suicide    0      M   64  White
# 2     2020 1     Suicide    0      F   39  White
# 3     2020 1     Suicide    0      M   20  Native American/Native Alaskan
# 4     2020 1     Suicide    0      F   65  White
# 5     2020 1     Suicide    0      M   31  Hispanic
# 6     2020 1     Suicide    0      M   30  White
# 7     2020 1     Homicide   1      M   59  White
# 8     2020 1     Suicide    0      M   24  Native American/Native Alaskan
# 9     2020 1     Suicide    0      M   80  White
# 10    2020 1     Suicide    0      M   77  White
# 11    2020 1     Suicide    0      M   19  Native American/Native Alaskan
# 12    2020 1     Homicide   1      M   26  White
# 13    2020 1     Homicide   1      M   32  Native American/Native Alaskan
# 14    2020 1     Suicide    0      M   79  White
# 15    2020 1     Suicide    0      F   25  Native American/Native Alaskan
# 16    2020 2     Suicide    0      M   57  White
# 17    2020 2     Suicide    0      M   47  White
# 18    2020 2     Suicide    0      M   26  Native American/Native Alaskan
# 19    2020 2     Homicide   0      M   16  Asian/Pacific Islander
# 20    2020 2     Homicide   0      F   51  Native American/Native Alaskan
# 21    2020 2     Suicide    0      M   67  White
# 22    2020 2     Suicide    0      M   81  White
# 23    2020 1     Homicide   0      F   70  White
# 24    2020 2     Suicide    0      M   32  Black
# 25    2020 1     Homicide   0      M   71  White
# 26    2020 3     Suicide    0      M   63  White
# 27    2020 2     Suicide    0      M   30  Native American/Native Alaskan
# 28    2020 3     Suicide    0      F   29  Native American/Native Alaskan
# 29    2020 3     Suicide    0      M   31  White
# 30    2020 3     Homicide   0      M   37  White
# ⋮     ⋮    ⋮     ⋮          ⋮      ⋮   ⋮   ⋮
# 45193 2020 11    Homicide   0      F   20  Black
# 45194 2020 12    Homicide   0      M   32  White
# 45195 2020 11    Homicide   0      F   52  Black
# 45196 2020 12    Homicide   1      M   35  Black
# 45197 2020 12    Homicide   0      M   32  Black
# 45198 2020 12    Suicide    0      M   65  White
# 45199 2020 12    Homicide   0      M   22  Asian/Pacific Islander
# 45200 2020 12    Homicide   0      M   38  Black
# 45201 2020 12    Homicide   0      M   46  Black
# 45202 2020 12    Homicide   1      M   52  Hispanic
# 45203 2020 12    Homicide   0      M   39  Black
# 45204 2020 12    Homicide   0      M   22  Black
# 45205 2020 12    Accidental 0      M   18  Asian/Pacific Islander
# 45206 2020 12    Homicide   0      M   22  Black
# 45207 2020 12    Suicide    0      M   23  Hispanic
# 45208 2020 12    Homicide   0      M   26  Black
# 45209 2020 12    Homicide   0      M   44  Black
# 45210 2020 12    Homicide   0      M   16  Hispanic
# 45211 2020 12    Homicide   0      M   62  Black
# 45212 2020 12    Homicide   0      M   24  Hispanic
# 45213 2020 12    Suicide    0      F   34  White
# 45214 2020 12    Homicide   0      F   54  Black
# 45215 2020 12    Homicide   0      M   32  Hispanic
# 45216 2020 12    Homicide   0      M   26  Black
# 45217 2020 12    Homicide   0      M   35  Black
# 45218 2020 12    Suicide    0      M   35  Hispanic
# 45219 2020 12    Homicide   0      M   34  Black
# 45220 2020 12    Homicide   0      M   26  Black
# 45221 2020 12    Homicide   0      M   24  Black
# 45222 2020 12    Homicide   1      M   18  Hispanic
#       hispanic place              education
# 1     No       Home               BA+
# 2     No       Home               Some college
# 3     No       Home               HS/GED
# 4     No       Home               HS/GED
# 5     Yes      Home               Less than HS
# 6     No       Home               BA+
# 7     No       Other unspecified  HS/GED
# 8     No       Other specified    HS/GED
# 9     No       Home               BA+
# 10    No       Home               HS/GED
# 11    No       Home               Less than HS
# 12    No       Other unspecified  Some college
# 13    No       Other unspecified  HS/GED
# 14    No       Home               BA+
# 15    No       Home               HS/GED
# 16    No       Other specified    HS/GED
# 17    No       Home               HS/GED
# 18    No       Home               HS/GED
# 19    No       Street             Less than HS
# 20    No       Home               BA+
# 21    No       Home               Some college
# 22    No       Home               HS/GED
# 23    No       Home               BA+
# 24    No       Home               Some college
# 25    No       Home               BA+
# 26    No       Home               HS/GED
# 27    No       Other specified    HS/GED
# 28    No       Home               HS/GED
# 29    No       Other specified    HS/GED
# 30    No       Home               HS/GED
# ⋮     ⋮        ⋮                  ⋮
# 45193 No       Home               Some college
# 45194 No       Other specified    HS/GED
# 45195 No       Home               BA+
# 45196 No       Other unspecified  HS/GED
# 45197 No       Street             Some college
# 45198 No       Home               BA+
# 45199 No       Street             Less than HS
# 45200 No       Home               Less than HS
# 45201 No       Home               Some college
# 45202 Yes      Other unspecified  HS/GED
# 45203 No       Street             HS/GED
# 45204 No       Other specified    HS/GED
# 45205 No       Home               HS/GED
# 45206 No       Street             HS/GED
# 45207 Yes      Street             HS/GED
# 45208 No       Home               Less than HS
# 45209 No       Street             HS/GED
# 45210 Yes      Street             Less than HS
# 45211 No       Home               HS/GED
# 45212 Yes      Sports             Some college
# 45213 No       Home               BA+
# 45214 No       Home               HS/GED
# 45215 Yes      Trade/service area HS/GED
# 45216 No       Street             Less than HS
# 45217 No       Home               HS/GED
# 45218 Yes      Home               Some college
# 45219 No       Street             HS/GED
# 45220 No       Street             HS/GED
# 45221 No       Trade/service area HS/GED
# 45222 Yes      Other unspecified  HS/GED

# %%
# Any null data?
sum(is.na(gunDeathsData_2020))
# Out:
# [1] 0

# %%
# Gun related deaths from 2020
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 41.675
mean(gunDeathsData_2020$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 41.675
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 37
median(gunDeathsData_2020$age)
# Out:
# [1] "Median value for the age column:"
# [1] 37

# %%
# Mode Age:
print("Most occuring value for the age column:") # 21
Mode(gunDeathsData_2020$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 21
# attr(,"freq")
# [1] 1231

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.721 years
SD(gunDeathsData_2020$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.72146

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2020$age ~ gunDeathsData_2020$race, data = gunDeathsData_2020,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2020$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2020$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2020$age ~ gunDeathsData_2020$sex, data = gunDeathsData_2020,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2020$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2020$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2020$age ~ gunDeathsData_2020$intent, data = gunDeathsData_2020,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2020 %>%
  count(gunDeathsData_2020$race)
# Out:
#   gunDeathsData_2020$race        n
# 1 Asian/Pacific Islander           628
# 2 Black                          14140
# 3 Hispanic                        5003
# 4 Native American/Native Alaskan   523
# 5 White                          24928

# %%
gunDeathsData_2020 %>%
  count(gunDeathsData_2020$sex)
# Out:
#   gunDeathsData_2020$sex n
# 1 F                       6241
# 2 M                      38981

# %%
gunDeathsData_2020 %>%
  count(gunDeathsData_2020$intent)
# Out:
#   gunDeathsData_2020$intent n
# 1 Accidental                  535
# 2 Homicide                  19994
# 3 Suicide                   24292
# 4 Undetermined                401

# %%
gunDeathsData_2020 %>%
  count(gunDeathsData_2020$month)
# Out:
#    gunDeathsData_2020$month n
# 1   1                       3494
# 2   2                       3151
# 3   3                       3475
# 4   4                       3245
# 5   5                       3700
# 6   6                       4001
# 7   7                       4276
# 8   8                       4157
# 9   9                       3914
# 10 10                       4003
# 11 11                       3919
# 12 12                       3887

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2020.Rmd")
# Out:
# [1] TRUE
