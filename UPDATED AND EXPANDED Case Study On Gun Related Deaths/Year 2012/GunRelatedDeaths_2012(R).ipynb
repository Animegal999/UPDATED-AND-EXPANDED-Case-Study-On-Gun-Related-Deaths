# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2012 <- read.csv("/content/guns_2012.csv", header = TRUE, sep = ",")
View(gunDeathsData_2012)
# Out:
#       year month intent       police sex age
# 1     2012 1     Suicide      0      M   34.00000
# 2     2012 1     Suicide      0      F   21.00000
# 3     2012 1     Suicide      0      M   60.00000
# 4     2012 2     Suicide      0      M   64.00000
# 5     2012 2     Suicide      0      M   31.00000
# 6     2012 2     Suicide      0      M   17.00000
# 7     2012 2     Undetermined 0      M   48.00000
# 8     2012 3     Suicide      0      M   41.00000
# 9     2012 2     Accidental   0      M   50.00000
# 10    2012 2     Suicide      0      M   43.43159
# 11    2012 2     Suicide      0      M   30.00000
# 12    2012 1     Suicide      0      M   21.00000
# 13    2012 3     Suicide      0      M   43.00000
# 14    2012 3     Suicide      0      M   34.00000
# 15    2012 3     Homicide     0      M   27.00000
# 16    2012 3     Suicide      0      M   27.00000
# 17    2012 3     Suicide      0      M   55.00000
# 18    2012 3     Suicide      0      M   53.00000
# 19    2012 3     Homicide     0      M   31.00000
# 20    2012 4     Suicide      0      M   51.00000
# 21    2012 4     Suicide      0      M   65.00000
# 22    2012 4     Suicide      0      F   52.00000
# 23    2012 4     Homicide     0      F   47.00000
# 24    2012 4     Suicide      0      M   19.00000
# 25    2012 4     Homicide     0      M   51.00000
# 26    2012 4     Homicide     0      M   41.00000
# 27    2012 4     Suicide      0      M   22.00000
# 28    2012 4     Suicide      0      M   21.00000
# 29    2012 4     Suicide      0      M   56.00000
# 30    2012 4     Homicide     0      M   43.00000
# ⋮     ⋮    ⋮     ⋮            ⋮      ⋮   ⋮
# 33534 2012 11    Homicide     0      M   26
# 33535 2012 11    Homicide     0      M   20
# 33536 2012 12    Suicide      0      M   46
# 33537 2012 11    Homicide     0      M   21
# 33538 2012 11    Homicide     0      M   28
# 33539 2012 11    Homicide     0      F   39
# 33540 2012 11    Homicide     0      M   20
# 33541 2012 11    Homicide     0      M   28
# 33542 2012 11    Suicide      0      M   53
# 33543 2012 12    Homicide     0      M   46
# 33544 2012 12    Homicide     1      M   46
# 33545 2012 12    Homicide     0      M   21
# 33546 2012 12    Homicide     0      M   25
# 33547 2012 12    Homicide     0      M   31
# 33548 2012 12    Suicide      0      M   89
# 33549 2012 12    Homicide     0      M   43
# 33550 2012 12    Homicide     0      F   32
# 33551 2012 12    Suicide      0      M   19
# 33552 2012 12    Homicide     0      M   26
# 33553 2012 12    Homicide     0      M   35
# 33554 2012 12    Homicide     0      M   41
# 33555 2012 12    Homicide     0      M   22
# 33556 2012 12    Suicide      0      M   44
# 33557 2012 12    Homicide     0      M   35
# 33558 2012 12    Homicide     0      M   23
# 33559 2012 12    Homicide     0      M   24
# 33560 2012 12    Homicide     0      M   17
# 33561 2012 12    Suicide      0      M   74
# 33562 2012 12    Homicide     0      M   31
# 33563 2012 12    Suicide      0      M   70
#       race                           hispanic place              education
# 1     Asian/Pacific Islander         No       Home               BA+
# 2     White                          No       Street             Some college
# 3     White                          No       Other specified    BA+
# 4     White                          No       Home               BA+
# 5     White                          No       Other specified    HS/GED
# 6     Native American/Native Alaskan No       Home               Less than HS
# 7     White                          No       Home               HS/GED
# 8     Native American/Native Alaskan No       Home               HS/GED
# 9     White                          No       Other specified    Some college
# 10    Black                          No       Home               Unknown
# 11    White                          No       Home               Some college
# 12    Native American/Native Alaskan No       Home               HS/GED
# 13    White                          No       Home               Less than HS
# 14    Native American/Native Alaskan No       Home               HS/GED
# 15    White                          No       Home               HS/GED
# 16    Native American/Native Alaskan No       Home               HS/GED
# 17    White                          No       Home               BA+
# 18    Native American/Native Alaskan No       Home               HS/GED
# 19    Asian/Pacific Islander         No       Home               Some college
# 20    White                          No       Home               HS/GED
# 21    Native American/Native Alaskan No       Home               HS/GED
# 22    White                          No       Home               HS/GED
# 23    Black                          No       Home               HS/GED
# 24    White                          No       Home               Some college
# 25    White                          No       Other specified    HS/GED
# 26    White                          No       Other specified    HS/GED
# 27    Native American/Native Alaskan No       Other specified    HS/GED
# 28    White                          No       Other specified    HS/GED
# 29    White                          No       Home               HS/GED
# 30    White                          No       Other specified    HS/GED
# ⋮     ⋮                              ⋮        ⋮                  ⋮
# 33534 Hispanic                       Yes      Home               Some college
# 33535 Black                          No       Home               Less than HS
# 33536 Black                          No       Home               BA+
# 33537 Black                          No       Street             HS/GED
# 33538 Black                          No       Other specified    Some college
# 33539 Black                          No       Home               BA+
# 33540 Black                          No       Home               HS/GED
# 33541 Black                          No       Other specified    Less than HS
# 33542 Black                          No       Home               HS/GED
# 33543 Hispanic                       Yes      Street             Less than HS
# 33544 Hispanic                       Yes      Other unspecified  HS/GED
# 33545 Black                          No       Street             HS/GED
# 33546 Black                          No       Street             HS/GED
# 33547 Black                          No       Street             BA+
# 33548 White                          No       Home               HS/GED
# 33549 Black                          No       Street             Less than HS
# 33550 Black                          No       Street             Some college
# 33551 White                          No       Other specified    Some college
# 33552 White                          No       Trade/service area HS/GED
# 33553 Hispanic                       Yes      Street             HS/GED
# 33554 Hispanic                       Yes      Home               Less than HS
# 33555 Hispanic                       Yes      Street             Less than HS
# 33556 Black                          No       Home               HS/GED
# 33557 Black                          No       Other specified    HS/GED
# 33558 Black                          No       Street             Less than HS
# 33559 White                          No       Street             Some college
# 33560 Black                          No       Street             HS/GED
# 33561 White                          No       Other specified    HS/GED
# 33562 Black                          No       Home               HS/GED
# 33563 White                          No       Other specified    Less than HS

# %%
# Any null data?
sum(is.na(gunDeathsData_2012))
# Out:
# [1] 0

# %%
# Gun related deaths from 2012
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.432
mean(gunDeathsData_2012$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.43159
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 41
median(gunDeathsData_2012$age)
# Out:
# [1] "Median value for the age column:"
# [1] 41

# %%
# Mode Age:
print("Most occuring value for the age column:") # 22
Mode(gunDeathsData_2012$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 22
# attr(,"freq")
# [1] 943

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.351 years
SD(gunDeathsData_2012$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.35134

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2012$age ~ gunDeathsData_2012$race, data = gunDeathsData_2012,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2012$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2012$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2012$age ~ gunDeathsData_2012$sex, data = gunDeathsData_2012,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2012$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2011$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2012$age ~ gunDeathsData_2012$intent, data = gunDeathsData_2012,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2012 %>%
  count(gunDeathsData_2012$race)
# Out:
#   gunDeathsData_2012$race        n
# 1 Asian/Pacific Islander           453
# 2 Black                           7946
# 3 Hispanic                        3061
# 4 Native American/Native Alaskan   310
# 5 White                          21793

# %%
gunDeathsData_2012 %>%
  count(gunDeathsData_2012$sex)
# Out:
#   gunDeathsData_2012$sex n
# 1 F                       4725
# 2 M                      28838

# %%
gunDeathsData_2012 %>%
  count(gunDeathsData_2012$intent)
# Out:
#   gunDeathsData_2012$intent n
# 1 Accidental                  548
# 2 Homicide                  12093
# 3 Suicide                   20666
# 4 Undetermined                256

# %%
gunDeathsData_2012 %>%
  count(gunDeathsData_2012$month)
# Out:
#    gunDeathsData_2012$month n
# 1   1                       2758
# 2   2                       2357
# 3   3                       2743
# 4   4                       2795
# 5   5                       2999
# 6   6                       2826
# 7   7                       3026
# 8   8                       2954
# 9   9                       2852
# 10 10                       2733
# 11 11                       2729
# 12 12                       2791

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2012.Rmd")
# Out:
# [1] TRUE
