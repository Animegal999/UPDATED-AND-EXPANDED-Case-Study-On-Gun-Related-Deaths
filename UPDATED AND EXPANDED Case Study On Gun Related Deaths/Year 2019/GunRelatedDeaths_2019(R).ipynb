# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2019 <- read.csv("/content/guns_2019.csv", header = TRUE, sep = ",")
View(gunDeathsData_2019)
# Out:
#       year month intent   police sex age race
# 1     2019 1     Suicide  0      M   50  White
# 2     2019 1     Suicide  0      M   14  Native American/Native Alaskan
# 3     2019 1     Suicide  0      M   18  White
# 4     2019 1     Homicide 0      M   24  Hispanic
# 5     2019 1     Suicide  0      M   87  White
# 6     2019 1     Suicide  0      M   50  Native American/Native Alaskan
# 7     2019 1     Suicide  0      M   48  Native American/Native Alaskan
# 8     2019 1     Suicide  0      M   29  Native American/Native Alaskan
# 9     2019 1     Suicide  0      M   48  White
# 10    2019 2     Suicide  0      M   23  Hispanic
# 11    2019 2     Suicide  0      M   61  White
# 12    2019 1     Suicide  0      M   34  Native American/Native Alaskan
# 13    2019 1     Homicide 0      M   19  White
# 14    2019 2     Homicide 0      F   30  Native American/Native Alaskan
# 15    2019 2     Homicide 0      F   46  White
# 16    2019 2     Suicide  0      F   26  Native American/Native Alaskan
# 17    2019 2     Homicide 1      M   28  White
# 18    2019 1     Suicide  0      M   49  White
# 19    2019 2     Suicide  0      M   16  Native American/Native Alaskan
# 20    2019 2     Suicide  0      M   42  White
# 21    2019 2     Suicide  0      M   55  Asian/Pacific Islander
# 22    2019 2     Suicide  0      M   57  White
# 23    2019 2     Suicide  0      M   35  Native American/Native Alaskan
# 24    2019 1     Suicide  0      M   24  White
# 25    2019 2     Homicide 0      F   47  White
# 26    2019 2     Suicide  0      M   48  White
# 27    2019 2     Suicide  0      M   57  White
# 28    2019 2     Suicide  0      M   27  White
# 29    2019 2     Suicide  0      M   59  White
# 30    2019 3     Suicide  0      M   58  White
# ⋮     ⋮    ⋮     ⋮        ⋮      ⋮   ⋮   ⋮
# 39678 2019 10    Homicide 0      M   41  Black
# 39679 2019 10    Homicide 0      M   25  Black
# 39680 2019 11    Homicide 0      M   25  Hispanic
# 39681 2019 10    Homicide 0      M   18  Black
# 39682 2019 11    Suicide  0      M   35  White
# 39683 2019 11    Suicide  0      M   61  White
# 39684 2019 11    Suicide  0      M   60  White
# 39685 2019 11    Homicide 0      F   24  Black
# 39686 2019 11    Homicide 0      M   31  Hispanic
# 39687 2019 11    Suicide  0      M   72  Hispanic
# 39688 2019 11    Homicide 0      M   51  Hispanic
# 39689 2019 11    Suicide  0      M   30  Black
# 39690 2019 11    Homicide 0      M   20  Hispanic
# 39691 2019 11    Suicide  0      M   22  Black
# 39692 2019 11    Homicide 0      M   34  Black
# 39693 2019 11    Homicide 0      M   29  Black
# 39694 2019 11    Homicide 0      M   19  Black
# 39695 2019 11    Homicide 0      M   32  Hispanic
# 39696 2019 11    Homicide 0      M   23  Black
# 39697 2019 11    Homicide 0      M   26  Hispanic
# 39698 2019 11    Suicide  0      M   83  Asian/Pacific Islander
# 39699 2019 12    Homicide 0      M   51  White
# 39700 2019 12    Suicide  0      M   66  White
# 39701 2019 12    Homicide 0      M   38  Black
# 39702 2019 12    Homicide 0      M   30  Hispanic
# 39703 2019 12    Homicide 0      M   16  White
# 39704 2019 12    Homicide 0      M   45  Black
# 39705 2019 12    Homicide 0      M   24  Black
# 39706 2019 12    Homicide 0      M   33  Black
# 39707 2019 12    Homicide 0      M   24  Black
#       hispanic place              education
# 1     No       Home               BA+
# 2     No       Home               Less than HS
# 3     No       Home               Less than HS
# 4     Yes      Home               HS/GED
# 5     No       Home               HS/GED
# 6     No       Home               Some college
# 7     No       Home               BA+
# 8     No       Other specified    Less than HS
# 9     No       Home               HS/GED
# 10    Yes      Other unspecified  Some college
# 11    No       Home               HS/GED
# 12    No       Home               HS/GED
# 13    No       Other unspecified  Less than HS
# 14    No       Street             HS/GED
# 15    No       Home               Some college
# 16    No       Home               HS/GED
# 17    No       Other unspecified  HS/GED
# 18    No       Home               BA+
# 19    No       Home               Less than HS
# 20    No       Home               Some college
# 21    No       Other specified    HS/GED
# 22    No       Home               Less than HS
# 23    No       Trade/service area HS/GED
# 24    No       School/instiution  Some college
# 25    No       Home               Some college
# 26    No       Home               Some college
# 27    No       Home               Some college
# 28    No       Home               HS/GED
# 29    No       Home               Less than HS
# 30    No       Home               HS/GED
# ⋮     ⋮        ⋮                  ⋮
# 39678 No       Street             HS/GED
# 39679 No       Street             Less than HS
# 39680 Yes      Street             HS/GED
# 39681 No       Street             Less than HS
# 39682 No       Home               Some college
# 39683 No       Home               BA+
# 39684 No       Home               Some college
# 39685 No       Home               Some college
# 39686 Yes      Street             HS/GED
# 39687 Yes      Home               HS/GED
# 39688 Yes      Other unspecified  HS/GED
# 39689 No       Home               HS/GED
# 39690 Yes      Other unspecified  Less than HS
# 39691 No       Home               Less than HS
# 39692 No       Street             Less than HS
# 39693 No       Street             Less than HS
# 39694 No       Street             Less than HS
# 39695 Yes      Street             Some college
# 39696 No       Trade/service area HS/GED
# 39697 Yes      Street             Some college
# 39698 No       Trade/service area Some college
# 39699 No       Home               HS/GED
# 39700 No       Home               HS/GED
# 39701 No       Other specified    HS/GED
# 39702 Yes      Street             Less than HS
# 39703 No       Street             Less than HS
# 39704 No       Street             Less than HS
# 39705 No       Street             HS/GED
# 39706 No       Home               HS/GED
# 39707 No       Street             Less than HS

# %%
# Any null data?
sum(is.na(gunDeathsData_2019))
# Out:
# [1] 0

# %%
# Gun related deaths from 2018
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.541
mean(gunDeathsData_2019$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.54055
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 40
median(gunDeathsData_2019$age)
# Out:
# [1] "Median value for the age column:"
# [1] 40

# %%
# Mode Age:
print("Most occuring value for the age column:") # 21
Mode(gunDeathsData_2019$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 21
# attr(,"freq")
# [1] 986

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.845 years
SD(gunDeathsData_2019$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.84521

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2019$age ~ gunDeathsData_2019$race, data = gunDeathsData_2019,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2019$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2019$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2019$age ~ gunDeathsData_2019$sex, data = gunDeathsData_2019,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2019$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2019$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2019$age ~ gunDeathsData_2019$intent, data = gunDeathsData_2019,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2019 %>%
  count(gunDeathsData_2019$race)
# Out:
#   gunDeathsData_2019$race        n
# 1 Asian/Pacific Islander           641
# 2 Black                          10410
# 3 Hispanic                        4058
# 4 Native American/Native Alaskan   386
# 5 White                          24212

# %%
gunDeathsData_2019 %>%
  count(gunDeathsData_2019$sex)
# Out:
#   gunDeathsData_2019$sex n
# 1 F                       5666
# 2 M                      34041

# %%
gunDeathsData_2019 %>%
  count(gunDeathsData_2019$intent)
# Out:
#   gunDeathsData_2019$intent n
# 1 Accidental                  486
# 2 Homicide                  14914
# 3 Suicide                   23941
# 4 Undetermined                366

# %%
gunDeathsData_2019 %>%
  count(gunDeathsData_2019$month)
# Out:
#    gunDeathsData_2019$month n
# 1   1                       3239
# 2   2                       2918
# 3   3                       3320
# 4   4                       3246
# 5   5                       3301
# 6   6                       3426
# 7   7                       3561
# 8   8                       3478
# 9   9                       3378
# 10 10                       3300
# 11 11                       3226
# 12 12                       3314

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2019.Rmd")
# Out:
# [1] TRUE
