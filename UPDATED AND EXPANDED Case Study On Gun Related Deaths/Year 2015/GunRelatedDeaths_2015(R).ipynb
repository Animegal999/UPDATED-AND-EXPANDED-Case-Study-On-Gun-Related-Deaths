# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2015 <- read.csv("/content/guns_2015.csv", header = TRUE, sep = ",")
View(gunDeathsData_2015)
# Out:
#       year month intent       police sex age race
# 1     2015 1     Suicide      0      M   48  White
# 2     2015 1     Suicide      0      F   19  White
# 3     2015 1     Suicide      0      M   33  White
# 4     2015 1     Homicide     0      F   23  Black
# 5     2015 1     Suicide      0      F   40  White
# 6     2015 1     Homicide     0      M   18  White
# 7     2015 1     Suicide      0      M   41  White
# 8     2015 1     Homicide     0      M   20  Hispanic
# 9     2015 1     Suicide      0      M   72  White
# 10    2015 1     Suicide      0      M   30  White
# 11    2015 2     Suicide      0      M   56  White
# 12    2015 2     Homicide     0      M   33  Hispanic
# 13    2015 2     Suicide      0      M   69  Native American/Native Alaskan
# 14    2015 2     Suicide      0      M   47  Native American/Native Alaskan
# 15    2015 2     Suicide      0      M   23  White
# 16    2015 2     Suicide      0      M   19  Native American/Native Alaskan
# 17    2015 1     Suicide      0      M   32  White
# 18    2015 2     Suicide      0      M   43  White
# 19    2015 2     Homicide     0      M   34  White
# 20    2015 1     Undetermined 0      F   25  Native American/Native Alaskan
# 21    2015 3     Suicide      0      M   49  White
# 22    2015 2     Homicide     0      M   30  Black
# 23    2015 3     Suicide      0      M   48  White
# 24    2015 1     Homicide     0      M   27  Black
# 25    2015 3     Homicide     0      M    7  Native American/Native Alaskan
# 26    2015 2     Homicide     0      M   31  Native American/Native Alaskan
# 27    2015 3     Homicide     0      F   56  Native American/Native Alaskan
# 28    2015 3     Suicide      0      M   19  White
# 29    2015 3     Suicide      0      M   12  Native American/Native Alaskan
# 30    2015 3     Suicide      0      F   38  White
# ⋮     ⋮    ⋮     ⋮            ⋮      ⋮   ⋮   ⋮
# 36223 2015 11    Homicide     0      M   23  Black
# 36224 2015 11    Suicide      0      M   34  Asian/Pacific Islander
# 36225 2015 11    Homicide     0      M   51  Black
# 36226 2015 11    Suicide      0      M   68  White
# 36227 2015 11    Homicide     0      M   19  Black
# 36228 2015 11    Homicide     0      M   24  Hispanic
# 36229 2015 12    Homicide     0      F   28  Black
# 36230 2015 11    Homicide     0      M   25  Black
# 36231 2015 11    Homicide     0      M   47  Black
# 36232 2015 12    Suicide      0      M   71  White
# 36233 2015 12    Homicide     0      M   27  Black
# 36234 2015 12    Homicide     0      M   44  Black
# 36235 2015 12    Suicide      0      M   39  Black
# 36236 2015 12    Suicide      0      M   71  White
# 36237 2015 12    Homicide     0      F   68  White
# 36238 2015 12    Suicide      0      M   30  Black
# 36239 2015 12    Homicide     0      M   30  Black
# 36240 2015 12    Homicide     0      M   29  Black
# 36241 2015 12    Homicide     0      M   68  Asian/Pacific Islander
# 36242 2015 12    Homicide     0      M   29  Black
# 36243 2015 12    Homicide     0      M   27  Black
# 36244 2015 12    Homicide     0      M   16  Black
# 36245 2015 12    Homicide     0      M   44  Black
# 36246 2015 12    Homicide     0      M   22  Black
# 36247 2015 12    Homicide     0      M   25  Black
# 36248 2015 12    Homicide     0      M   21  Hispanic
# 36249 2015 12    Homicide     0      M   31  Black
# 36250 2015 12    Homicide     0      M   16  Black
# 36251 2015 12    Homicide     0      M   35  Black
# 36252 2015 12    Homicide     0      M   16  Black
#       hispanic place             education
# 1     No       Home              HS/GED
# 2     No       Other specified   HS/GED
# 3     No       Home              BA+
# 4     No       Home              HS/GED
# 5     No       Other unspecified BA+
# 6     No       Other specified   HS/GED
# 7     No       Home              BA+
# 8     Yes      Other specified   HS/GED
# 9     No       Home              HS/GED
# 10    No       Other unspecified HS/GED
# 11    No       Home              Some college
# 12    Yes      Other specified   HS/GED
# 13    No       Home              Some college
# 14    No       Home              HS/GED
# 15    No       Home              Some college
# 16    No       Home              HS/GED
# 17    No       Home              HS/GED
# 18    No       Home              Some college
# 19    No       Home              HS/GED
# 20    No       Home              Unknown
# 21    No       Home              Some college
# 22    No       Other unspecified HS/GED
# 23    No       Other specified   BA+
# 24    No       Home              Some college
# 25    No       Home              Less than HS
# 26    No       Home              HS/GED
# 27    No       Other specified   Less than HS
# 28    No       Other specified   HS/GED
# 29    No       Other specified   Less than HS
# 30    No       Home              HS/GED
# ⋮     ⋮        ⋮                 ⋮
# 36223 No       Street            HS/GED
# 36224 No       Home              HS/GED
# 36225 No       Home              BA+
# 36226 No       Home              BA+
# 36227 No       Street            Less than HS
# 36228 Yes      Street            Less than HS
# 36229 No       Home              Some college
# 36230 No       Other specified   Less than HS
# 36231 No       Other specified   HS/GED
# 36232 No       Home              Some college
# 36233 No       Street            HS/GED
# 36234 No       Street            HS/GED
# 36235 No       Street            Some college
# 36236 No       Home              HS/GED
# 36237 No       Home              Less than HS
# 36238 No       Other unspecified Less than HS
# 36239 No       Street            HS/GED
# 36240 No       Street            Less than HS
# 36241 No       Street            HS/GED
# 36242 No       Other unspecified HS/GED
# 36243 No       Street            Some college
# 36244 No       Home              Less than HS
# 36245 No       Street            Less than HS
# 36246 No       Other unspecified HS/GED
# 36247 No       Street            HS/GED
# 36248 Yes      Other unspecified Less than HS
# 36249 No       Street            HS/GED
# 36250 No       Other specified   Less than HS
# 36251 No       Street            Less than HS
# 36252 No       Home              Less than HS

# %%
# Any null data?
sum(is.na(gunDeathsData_2015))
# Out:
# [1] 0

# %%
# Gun related deaths from 2015
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.494
mean(gunDeathsData_2015$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.49421
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 41
median(gunDeathsData_2015$age)
# Out:
# [1] "Median value for the age column:"
# [1] 41

# %%
# Mode Age:
print("Most occuring value for the age column:") # 24
Mode(gunDeathsData_2015$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 24
# attr(,"freq")
# [1] 963

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.551 years
SD(gunDeathsData_2015$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.55083

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2015$age ~ gunDeathsData_2015$race, data = gunDeathsData_2015,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2015$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2015$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2015$age ~ gunDeathsData_2015$sex, data = gunDeathsData_2015,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2015$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2015$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2015$age ~ gunDeathsData_2015$intent, data = gunDeathsData_2015,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2015 %>%
  count(gunDeathsData_2015$race)
# Out:
#   gunDeathsData_2015$race        n
# 1 Asian/Pacific Islander           509
# 2 Black                           8939
# 3 Hispanic                        3332
# 4 Native American/Native Alaskan   353
# 5 White                          23119

# %%
gunDeathsData_2015 %>%
  count(gunDeathsData_2015$sex)
# Out:
#   gunDeathsData_2015$sex n
# 1 F                       5220
# 2 M                      31032

# %%
gunDeathsData_2015 %>%
  count(gunDeathsData_2015$intent)
# Out:
#   gunDeathsData_2015$intent n
# 1 Accidental                  489
# 2 Homicide                  13458
# 3 Suicide                   22018
# 4 Undetermined                287

# %%
gunDeathsData_2015 %>%
  count(gunDeathsData_2015$month)
# Out:
#    gunDeathsData_2015$month n
# 1   1                       2963
# 2   2                       2489
# 3   3                       3038
# 4   4                       2955
# 5   5                       3167
# 6   6                       3035
# 7   7                       3345
# 8   8                       3210
# 9   9                       3056
# 10 10                       3006
# 11 11                       2923
# 12 12                       3065

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2015.Rmd")
# Out:
# [1] TRUE
