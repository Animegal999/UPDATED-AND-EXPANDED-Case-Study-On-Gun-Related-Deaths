# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2017 <- read.csv("/content/guns_2017.csv", header = TRUE, sep = ",")
View(gunDeathsData_2017)
# Out:
#       year month intent       police sex age race
# 1     2017 1     Suicide      0      F   34  Native American/Native Alaskan
# 2     2017 1     Suicide      0      M   16  Native American/Native Alaskan
# 3     2017 1     Suicide      0      M   31  Black
# 4     2017 1     Suicide      0      F   21  Native American/Native Alaskan
# 5     2017 1     Homicide     0      M   17  Hispanic
# 6     2017 1     Suicide      0      M   17  Native American/Native Alaskan
# 7     2017 1     Suicide      0      M   81  White
# 8     2017 1     Suicide      0      M   19  Native American/Native Alaskan
# 9     2017 1     Suicide      0      M   75  White
# 10    2017 2     Homicide     0      M   29  Native American/Native Alaskan
# 11    2017 1     Homicide     0      M   49  White
# 12    2017 1     Suicide      0      M   29  White
# 13    2017 2     Suicide      0      M   32  Native American/Native Alaskan
# 14    2017 1     Undetermined 0      M   32  Native American/Native Alaskan
# 15    2017 2     Homicide     0      M   69  Native American/Native Alaskan
# 16    2017 1     Homicide     0      M   19  Black
# 17    2017 1     Suicide      0      M   67  White
# 18    2017 2     Suicide      0      M   20  White
# 19    2017 2     Suicide      0      M   62  White
# 20    2017 2     Homicide     0      F   37  White
# 21    2017 2     Undetermined 0      M   37  White
# 22    2017 2     Suicide      0      M   26  Asian/Pacific Islander
# 23    2017 2     Suicide      0      M   21  Asian/Pacific Islander
# 24    2017 2     Suicide      0      M   54  White
# 25    2017 3     Suicide      0      M   31  White
# 26    2017 2     Homicide     0      F   24  Hispanic
# 27    2017 3     Homicide     0      M   32  White
# 28    2017 2     Suicide      0      M   70  White
# 29    2017 2     Homicide     0      M   35  Black
# 30    2017 3     Suicide      0      M   32  Black
# ⋮     ⋮    ⋮     ⋮            ⋮      ⋮   ⋮   ⋮
# 39744 2017 11    Homicide     0      M   33  Black
# 39745 2017 11    Homicide     0      M   38  Black
# 39746 2017 11    Homicide     0      M   20  Black
# 39747 2017 12    Homicide     0      M   30  Black
# 39748 2017 12    Suicide      0      M   57  Black
# 39749 2017 12    Homicide     0      M   40  Hispanic
# 39750 2017 12    Homicide     0      M   20  Black
# 39751 2017 11    Homicide     0      M   32  Black
# 39752 2017 12    Homicide     1      M   69  Hispanic
# 39753 2017 12    Homicide     0      M   27  Hispanic
# 39754 2017 12    Homicide     0      M   17  Hispanic
# 39755 2017 12    Homicide     0      M   37  Black
# 39756 2017 12    Homicide     0      M   80  White
# 39757 2017 12    Homicide     0      M   49  Black
# 39758 2017 12    Homicide     0      M   32  Black
# 39759 2017 12    Homicide     0      M   39  Black
# 39760 2017 12    Homicide     1      M   48  Black
# 39761 2017 12    Homicide     0      M   24  Black
# 39762 2017 12    Suicide      0      M   16  Hispanic
# 39763 2017 12    Homicide     0      M   21  Asian/Pacific Islander
# 39764 2017 12    Homicide     0      M   33  Black
# 39765 2017 12    Homicide     0      M   19  Black
# 39766 2017 12    Homicide     0      M   48  Hispanic
# 39767 2017 12    Homicide     0      F   35  White
# 39768 2017 12    Homicide     0      M   19  Hispanic
# 39769 2017 12    Homicide     0      M   16  Hispanic
# 39770 2017 12    Suicide      0      M   48  White
# 39771 2017 12    Homicide     0      M   16  Hispanic
# 39772 2017 12    Homicide     0      M   38  Black
# 39773 2017 12    Suicide      0      M   65  White
#       hispanic place              education
# 1     No       Home               Some college
# 2     No       Home               Less than HS
# 3     No       Home               HS/GED
# 4     No       Home               HS/GED
# 5     Yes      Other specified    Less than HS
# 6     No       Other specified    HS/GED
# 7     No       Home               Some college
# 8     No       Other specified    Less than HS
# 9     No       Home               HS/GED
# 10    No       Street             HS/GED
# 11    No       Home               HS/GED
# 12    No       Home               HS/GED
# 13    No       Home               HS/GED
# 14    No       Home               HS/GED
# 15    No       Home               Some college
# 16    No       Other unspecified  HS/GED
# 17    No       Other specified    Some college
# 18    No       Home               Some college
# 19    No       Home               BA+
# 20    No       Home               HS/GED
# 21    No       Home               BA+
# 22    No       Home               HS/GED
# 23    No       Trade/service area Some college
# 24    No       Home               Some college
# 25    No       Home               Some college
# 26    Yes      Home               Some college
# 27    No       Other specified    HS/GED
# 28    No       Home               HS/GED
# 29    No       Home               HS/GED
# 30    No       Home               Less than HS
# ⋮     ⋮        ⋮                  ⋮
# 39744 No       Home               Some college
# 39745 No       Home               HS/GED
# 39746 No       Trade/service area HS/GED
# 39747 No       Other specified    HS/GED
# 39748 No       Trade/service area BA+
# 39749 Yes      Other unspecified  Less than HS
# 39750 No       Street             HS/GED
# 39751 No       Other specified    HS/GED
# 39752 Yes      Other unspecified  Unknown
# 39753 Yes      Street             Some college
# 39754 Yes      Street             Less than HS
# 39755 No       Home               Some college
# 39756 No       Other specified    Less than HS
# 39757 No       Trade/service area HS/GED
# 39758 No       Street             HS/GED
# 39759 No       Other unspecified  BA+
# 39760 No       Other unspecified  HS/GED
# 39761 No       Street             HS/GED
# 39762 Yes      Home               Less than HS
# 39763 No       Other unspecified  Less than HS
# 39764 No       Street             Less than HS
# 39765 No       Street             Less than HS
# 39766 Yes      Street             Some college
# 39767 No       Home               HS/GED
# 39768 Yes      Street             HS/GED
# 39769 Yes      Street             Less than HS
# 39770 No       Home               Unknown
# 39771 Yes      Street             Less than HS
# 39772 No       Street             HS/GED
# 39773 No       Home               HS/GED

# %%
# Any null data?
sum(is.na(gunDeathsData_2017))
# Out:
# [1] 0

# %%
# Gun related deaths from 2017
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.056
mean(gunDeathsData_2017$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.0956
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 40
median(gunDeathsData_2017$age)
# Out:
# [1] "Median value for the age column:"
# [1] 40

# %%
# Mode Age:
print("Most occuring value for the age column:") # 25
Mode(gunDeathsData_2017$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 25
# attr(,"freq")
# [1] 1027

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.674 years
SD(gunDeathsData_2017$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.67378

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2017$age ~ gunDeathsData_2017$race, data = gunDeathsData_2017,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2017$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2016$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2017$age ~ gunDeathsData_2017$sex, data = gunDeathsData_2017,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2017$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2016$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2017$age ~ gunDeathsData_2017$intent, data = gunDeathsData_2017,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2017 %>%
  count(gunDeathsData_2017$race)
# Out:
#   gunDeathsData_2017$race        n
# 1 Asian/Pacific Islander           588
# 2 Black                          10142
# 3 Hispanic                        3884
# 4 Native American/Native Alaskan   398
# 5 White                          24761

# %%
gunDeathsData_2017 %>%
  count(gunDeathsData_2017$sex)
# Out:
#   gunDeathsData_2017$sex n
# 1 F                       5711
# 2 M                      34062

# %%
gunDeathsData_2017 %>%
  count(gunDeathsData_2017$intent)
# Out:
#   gunDeathsData_2017$intent n
# 1 Accidental                  486
# 2 Homicide                  15095
# 3 Suicide                   23854
# 4 Undetermined                338

# %%
gunDeathsData_2017 %>%
  count(gunDeathsData_2017$month)
# Out:
#    gunDeathsData_2017$month n
# 1   1                       3336
# 2   2                       2921
# 3   3                       3143
# 4   4                       3313
# 5   5                       3533
# 6   6                       3326
# 7   7                       3510
# 8   8                       3429
# 9   9                       3229
# 10 10                       3498
# 11 11                       3265
# 12 12                       3270

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2017.Rmd")
# Out:
# [1] TRUE
