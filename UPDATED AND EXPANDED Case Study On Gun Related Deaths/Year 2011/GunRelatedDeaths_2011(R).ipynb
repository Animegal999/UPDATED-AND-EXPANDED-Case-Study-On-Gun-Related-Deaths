# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2011 <- read.csv("/content/guns_2011.csv", header = TRUE, sep = ",")
View(gunDeathsData_2011)
# Out:
#       year month intent       police sex age race
# 1     2011 1     Suicide      0      M   53  White
# 2     2011 1     Suicide      0      M   58  White
# 3     2011 1     Suicide      0      M   28  White
# 4     2011 2     Suicide      0      M   62  White
# 5     2011 1     Homicide     0      M   66  White
# 6     2011 1     Suicide      0      M   31  Native American/Native Alaskan
# 7     2011 1     Suicide      0      F   25  White
# 8     2011 2     Suicide      0      F   18  Native American/Native Alaskan
# 9     2011 1     Suicide      0      M   27  Hispanic
# 10    2011 3     Homicide     0      M   59  White
# 11    2011 2     Suicide      0      M   21  White
# 12    2011 3     Suicide      0      M   60  White
# 13    2011 3     Suicide      0      M   23  White
# 14    2011 3     Undetermined 0      M   26  White
# 15    2011 3     Homicide     0      M   19  Black
# 16    2011 3     Suicide      0      M   58  Hispanic
# 17    2011 2     Homicide     0      M   19  Native American/Native Alaskan
# 18    2011 3     Suicide      0      F   25  Native American/Native Alaskan
# 19    2011 4     Suicide      0      F   45  White
# 20    2011 4     Suicide      0      F   64  White
# 21    2011 4     Suicide      0      M   70  White
# 22    2011 4     Suicide      0      M   68  White
# 23    2011 5     Suicide      0      M   23  White
# 24    2011 5     Suicide      0      M   26  White
# 25    2011 4     Homicide     0      F   58  Asian/Pacific Islander
# 26    2011 4     Homicide     0      F   43  Native American/Native Alaskan
# 27    2011 4     Suicide      0      M   52  Native American/Native Alaskan
# 28    2011 5     Suicide      0      M   24  White
# 29    2011 5     Accidental   0      M   11  Native American/Native Alaskan
# 30    2011 4     Suicide      0      F   47  White
# ⋮     ⋮    ⋮     ⋮            ⋮      ⋮   ⋮   ⋮
# 32322 2011 12    Homicide     0      M   39  Black
# 32323 2011 12    Homicide     0      M   18  Black
# 32324 2011 12    Homicide     0      M   26  Black
# 32325 2011 12    Homicide     0      M   38  Black
# 32326 2011 12    Homicide     0      M   20  Black
# 32327 2011 12    Homicide     0      M   20  Black
# 32328 2011 12    Homicide     0      M   48  Black
# 32329 2011 12    Homicide     0      M   47  White
# 32330 2011 12    Homicide     0      M   37  Black
# 32331 2011 12    Homicide     0      M   30  Black
# 32332 2011 12    Homicide     0      F   25  White
# 32333 2011 12    Homicide     0      F   42  Black
# 32334 2011 12    Homicide     0      F   33  Hispanic
# 32335 2011 12    Homicide     0      M   28  Black
# 32336 2011 12    Homicide     0      M   30  Black
# 32337 2011 12    Suicide      0      M   29  Black
# 32338 2011 12    Homicide     0      M   22  Black
# 32339 2011 12    Homicide     0      M   51  Hispanic
# 32340 2011 12    Homicide     0      M   46  Black
# 32341 2011 12    Homicide     0      M   16  Black
# 32342 2011 12    Homicide     0      F   18  Hispanic
# 32343 2011 12    Suicide      0      M   36  Hispanic
# 32344 2011 12    Homicide     0      M   17  Black
# 32345 2011 12    Homicide     0      M   43  Hispanic
# 32346 2011 12    Homicide     0      M   28  Black
# 32347 2011 12    Homicide     0      M   15  Black
# 32348 2011 12    Suicide      0      M   50  Black
# 32349 2011 12    Homicide     0      M   18  Black
# 32350 2011 12    Homicide     0      F   51  White
# 32351 2011 12    Homicide     0      M   19  Black
#       hispanic place              education
# 1     No       Home               HS/GED
# 2     No       Home               Some college
# 3     No       Home               HS/GED
# 4     No       Other specified    Some college
# 5     No       Home               HS/GED
# 6     No       Home               HS/GED
# 7     No       Home               Some college
# 8     No       Home               Less than HS
# 9     Yes      Home               HS/GED
# 10    No       Home               Some college
# 11    No       Other specified    Some college
# 12    No       Home               HS/GED
# 13    No       Home               HS/GED
# 14    No       Home               HS/GED
# 15    No       Home               HS/GED
# 16    Yes      Home               BA+
# 17    No       Other specified    Less than HS
# 18    No       Home               HS/GED
# 19    No       Home               BA+
# 20    No       Home               BA+
# 21    No       Home               BA+
# 22    No       Home               HS/GED
# 23    No       Home               HS/GED
# 24    No       Other specified    Some college
# 25    No       Home               BA+
# 26    No       Other specified    Some college
# 27    No       Home               HS/GED
# 28    No       Home               HS/GED
# 29    No       Other specified    Less than HS
# 30    No       Home               HS/GED
# ⋮     ⋮        ⋮                  ⋮
# 32322 No       Street             HS/GED
# 32323 No       Home               Less than HS
# 32324 No       Trade/service area HS/GED
# 32325 No       Other unspecified  HS/GED
# 32326 No       Street             Less than HS
# 32327 No       Home               Less than HS
# 32328 No       Other unspecified  Some college
# 32329 No       Home               Some college
# 32330 No       Other specified    HS/GED
# 32331 No       Home               Some college
# 32332 No       Home               HS/GED
# 32333 No       Home               BA+
# 32334 Yes      Street             Less than HS
# 32335 No       Other specified    Less than HS
# 32336 No       Other unspecified  HS/GED
# 32337 No       Other specified    HS/GED
# 32338 No       Home               Some college
# 32339 Yes      Home               Less than HS
# 32340 No       Home               HS/GED
# 32341 No       Street             Less than HS
# 32342 Yes      Street             HS/GED
# 32343 Yes      Street             HS/GED
# 32344 No       Street             Less than HS
# 32345 Yes      Home               Less than HS
# 32346 No       Street             HS/GED
# 32347 No       Other specified    Less than HS
# 32348 No       Home               BA+
# 32349 No       Street             Less than HS
# 32350 No       Home               Unknown
# 32351 No       Home               Less than HS

# %%
# Any null data?
sum(is.na(gunDeathsData_2011))
# Out:
# [1] 0

# %%
# Gun related deaths from 2011
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.249
mean(gunDeathsData_2011$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.24875
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 41
median(gunDeathsData_2011$age)
# Out:
# [1] "Median value for the age column:"
# [1] 41

# %%
# Mode Age:
print("Most occuring value for the age column:") # 22
Mode(gunDeathsData_2011$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 22
# attr(,"freq")
# [1] 861

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.348 years
SD(gunDeathsData_2011$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.34777

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2011$age ~ gunDeathsData_2011$race, data = gunDeathsData_2011,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2011$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2011$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2011$age ~ gunDeathsData_2011$sex, data = gunDeathsData_2011,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2011$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2011$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2011$age ~ gunDeathsData_2011$intent, data = gunDeathsData_2011,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2011 %>%
  count(gunDeathsData_2011$race)
# Out:
#   gunDeathsData_2011$race        n
# 1 Asian/Pacific Islander           417
# 2 Black                           7457
# 3 Hispanic                        2947
# 4 Native American/Native Alaskan   276
# 5 White                          21254

# %%
gunDeathsData_2011 %>%
  count(gunDeathsData_2011$sex)
# Out:
#   gunDeathsData_2011$sex n
# 1 F                       4613
# 2 M                      27738

# %%
gunDeathsData_2011 %>%
  count(gunDeathsData_2011$intent)
# Out:
#   gunDeathsData_2011$intent n
# 1 Accidental                  591
# 2 Homicide                  11522
# 3 Suicide                   19990
# 4 Undetermined                248

# %%
gunDeathsData_2011 %>%
  count(gunDeathsData_2011$month)
# Out:
#    gunDeathsData_2011$month n
# 1   1                       2551
# 2   2                       2158
# 3   3                       2704
# 4   4                       2855
# 5   5                       2858
# 6   6                       2701
# 7   7                       3052
# 8   8                       2828
# 9   9                       2679
# 10 10                       2748
# 11 11                       2579
# 12 12                       2638

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2011.Rmd")
# Out:
# [1] TRUE
