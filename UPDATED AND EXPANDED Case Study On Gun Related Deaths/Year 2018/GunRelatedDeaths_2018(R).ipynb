# %%
install.packages("ggplot2")
install.packages("tinytex")
install.packages("rmarkdown", dep = TRUE)
install.packages("plotly")
install.packages("DescTools")
install.packages("dplyr")

library(ggplot2)
library(tinytex)
library(rmarkdown)
library(plotly)
library(DescTools)
library(dplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘zoo’, ‘xts’, ‘PKI’, ‘packrat’, ‘renv’, ‘V8’, ‘dygraphs’, ‘rsconnect’, ‘katex’, ‘cleanrmd’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘crosstalk’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Exact’, ‘gld’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
gunDeathsData_2018 <- read.csv("/content/guns_2018.csv", header = TRUE, sep = ",")
View(gunDeathsData_2018)
# Out:
#       year month intent       police sex age race
# 1     2018 1     Suicide      0      M   46  White
# 2     2018 1     Homicide     0      M   39  Black
# 3     2018 1     Suicide      0      M   67  White
# 4     2018 1     Suicide      0      M   36  White
# 5     2018 1     Suicide      0      F   64  Native American/Native Alaskan
# 6     2018 1     Suicide      0      M   62  White
# 7     2018 1     Homicide     0      F   19  Hispanic
# 8     2018 1     Suicide      0      M   24  Native American/Native Alaskan
# 9     2018 1     Suicide      0      M   45  White
# 10    2018 1     Homicide     0      M   32  Black
# 11    2018 1     Suicide      0      F   77  White
# 12    2018 1     Suicide      0      F   33  White
# 13    2018 1     Homicide     0      M   52  Native American/Native Alaskan
# 14    2018 1     Suicide      0      M   69  White
# 15    2018 1     Homicide     0      F   26  White
# 16    2018 2     Suicide      0      M   72  White
# 17    2018 1     Suicide      0      M   16  Native American/Native Alaskan
# 18    2018 2     Suicide      0      M   59  White
# 19    2018 2     Suicide      0      M   27  White
# 20    2018 2     Suicide      0      M   17  White
# 21    2018 2     Suicide      0      M   18  Native American/Native Alaskan
# 22    2018 1     Suicide      0      M   78  White
# 23    2018 2     Suicide      0      M   64  White
# 24    2018 2     Suicide      0      F   37  White
# 25    2018 2     Suicide      0      M   47  White
# 26    2018 2     Suicide      0      M   32  White
# 27    2018 2     Suicide      0      M   34  White
# 28    2018 1     Undetermined 0      F   33  Native American/Native Alaskan
# 29    2018 2     Suicide      0      M   19  Native American/Native Alaskan
# 30    2018 1     Suicide      0      M   62  White
# ⋮     ⋮    ⋮     ⋮            ⋮      ⋮   ⋮   ⋮
# 39711 2018 10    Homicide     0      M   29  Black
# 39712 2018 10    Homicide     0      M   77  White
# 39713 2018 10    Suicide      0      M   25  Asian/Pacific Islander
# 39714 2018 11    Homicide     0      M   26  Hispanic
# 39715 2018 11    Homicide     0      M   27  Black
# 39716 2018 11    Homicide     0      M   22  Black
# 39717 2018 11    Suicide      0      M   64  White
# 39718 2018 11    Homicide     0      M   26  Hispanic
# 39719 2018 11    Homicide     0      M   25  Black
# 39720 2018 11    Homicide     0      F   52  Hispanic
# 39721 2018 11    Suicide      0      M   45  Hispanic
# 39722 2018 11    Suicide      0      M   25  Black
# 39723 2018 11    Homicide     0      M   29  Black
# 39724 2018 11    Suicide      0      M   95  White
# 39725 2018 11    Homicide     0      M   43  White
# 39726 2018 11    Homicide     0      F   45  Hispanic
# 39727 2018 12    Homicide     0      M   21  Black
# 39728 2018 12    Homicide     0      M   35  Black
# 39729 2018 12    Homicide     0      M   23  White
# 39730 2018 12    Suicide      0      M   40  Hispanic
# 39731 2018 12    Homicide     0      M   38  Black
# 39732 2018 12    Homicide     1      M   50  Asian/Pacific Islander
# 39733 2018 12    Homicide     0      M   24  Hispanic
# 39734 2018 12    Homicide     0      M   23  Hispanic
# 39735 2018 12    Homicide     0      M   28  Hispanic
# 39736 2018 12    Homicide     0      M   18  Black
# 39737 2018 12    Homicide     0      M   32  Black
# 39738 2018 12    Homicide     0      M   23  Black
# 39739 2018 12    Homicide     0      M   32  Black
# 39740 2018 12    Homicide     0      M   62  White
#       hispanic place              education
# 1     No       Home               Less than HS
# 2     No       Other specified    HS/GED
# 3     No       Home               Some college
# 4     No       Other specified    HS/GED
# 5     No       Home               Some college
# 6     No       Home               HS/GED
# 7     Yes      Trade/service area HS/GED
# 8     No       Other specified    Less than HS
# 9     No       Home               BA+
# 10    No       Home               BA+
# 11    No       Home               Some college
# 12    No       Home               HS/GED
# 13    No       Home               Some college
# 14    No       Home               Some college
# 15    No       Home               HS/GED
# 16    No       Home               HS/GED
# 17    No       Home               Less than HS
# 18    No       Trade/service area Some college
# 19    No       Home               HS/GED
# 20    No       Home               Less than HS
# 21    No       Home               Less than HS
# 22    No       Home               HS/GED
# 23    No       Home               Less than HS
# 24    No       Home               Some college
# 25    No       Home               HS/GED
# 26    No       Other specified    BA+
# 27    No       Other specified    BA+
# 28    No       Home               Some college
# 29    No       Other unspecified  HS/GED
# 30    No       Other specified    Some college
# ⋮     ⋮        ⋮                  ⋮
# 39711 No       Home               Unknown
# 39712 No       Home               HS/GED
# 39713 No       Other unspecified  HS/GED
# 39714 Yes      Other specified    HS/GED
# 39715 No       Street             HS/GED
# 39716 No       Street             HS/GED
# 39717 No       Home               HS/GED
# 39718 Yes      Street             Less than HS
# 39719 No       Street             Some college
# 39720 Yes      Home               Less than HS
# 39721 Yes      Home               HS/GED
# 39722 No       Home               HS/GED
# 39723 No       Home               Some college
# 39724 No       Home               HS/GED
# 39725 No       Street             Less than HS
# 39726 Yes      Home               Some college
# 39727 No       Home               Less than HS
# 39728 No       Street             HS/GED
# 39729 No       Street             HS/GED
# 39730 Yes      Home               HS/GED
# 39731 No       Trade/service area HS/GED
# 39732 No       Other unspecified  BA+
# 39733 Yes      Other specified    HS/GED
# 39734 Yes      Other specified    Some college
# 39735 Yes      School/instiution  HS/GED
# 39736 No       Other specified    Less than HS
# 39737 No       Street             Some college
# 39738 No       Street             HS/GED
# 39739 No       Home               BA+
# 39740 No       Home               Some college

# %%
# Any null data?
sum(is.na(gunDeathsData_2018))
# Out:
# [1] 0

# %%
# Gun related deaths from 2018
# Statistical information

# Mean for each numeric column:
# Only one numeric column was found: Age
print("Mean values for each numeric column:")
print("Mean Age: ") # 43.657
mean(gunDeathsData_2018$age)
print("-----------------------------")
# Out:
# [1] "Mean values for each numeric column:"
# [1] "Mean Age: "
# [1] 43.65714
# [1] "-----------------------------"

# %%
# Median Age:
print("Median value for the age column:") # 40
median(gunDeathsData_2018$age)
# Out:
# [1] "Median value for the age column:"
# [1] 40

# %%
# Mode Age:
print("Most occuring value for the age column:") # 23
Mode(gunDeathsData_2018$age)
# Out:
# [1] "Most occuring value for the age column:"
# [1] 23
# attr(,"freq")
# [1] 977

# %%
# Standard Deviation Age:
print("Standard Deviation of the age:") #19.756 years
SD(gunDeathsData_2018$age)
# Out:
# [1] "Standard Deviation of the age:"
# [1] 19.75591

# %%
# creating boxplot on age and race:
boxplot(gunDeathsData_2018$age ~ gunDeathsData_2018$race, data = gunDeathsData_2018,
        main = "Age of Victims of Gun-related Deaths by Race",
        xlab = "Race",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Race”

# %%
# Constructing the histogram:

hist(gunDeathsData_2018$age, xlab="Victims of Gun Violence By Age", col = "red", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2018$age”

# %%
# Creating a boxplot on age and gender:
boxplot(gunDeathsData_2018$age ~ gunDeathsData_2018$sex, data = gunDeathsData_2018,
        main = "Age of Victims of Gun-related Deaths by Gender",
        xlab = "Gender",
        ylab = "Age")
# Out:
# Plot with title “Age of Victims of Gun-related Deaths by Gender”

# %%
# Constructing the histogram for number of deaths by month:

hist(gunDeathsData_2018$month, xlab="Total Victims of Gun Violence By Month", col = "blue", border = "black")
# Out:
# Plot with title “Histogram of gunDeathsData_2018$month”

# %%
# Creating a boxplot on age and intentions behind the gun:
boxplot(gunDeathsData_2018$age ~ gunDeathsData_2018$intent, data = gunDeathsData_2018,
  main = "Age of victims of Gun-related Deaths by Intent",
  xlab = "Intentions With the Gun",
  ylab = "Age")

# Homicides have the most outliers
# Out:
# Plot with title “Age of victims of Gun-related Deaths by Intent”

# %%
gunDeathsData_2018 %>%
  count(gunDeathsData_2018$race)
# Out:
#   gunDeathsData_2018$race        n
# 1 Asian/Pacific Islander           618
# 2 Black                           9824
# 3 Hispanic                        4018
# 4 Native American/Native Alaskan   428
# 5 White                          24852

# %%
gunDeathsData_2018 %>%
  count(gunDeathsData_2018$sex)
# Out:
#   gunDeathsData_2018$sex n
# 1 F                       5785
# 2 M                      33955

# %%
gunDeathsData_2018 %>%
  count(gunDeathsData_2018$intent)
# Out:
#   gunDeathsData_2018$intent n
# 1 Accidental                  458
# 2 Homicide                  14497
# 3 Suicide                   24432
# 4 Undetermined                353

# %%
gunDeathsData_2018 %>%
  count(gunDeathsData_2018$month)
# Out:
#    gunDeathsData_2018$month n
# 1   1                       3565
# 2   2                       2957
# 3   3                       3264
# 4   4                       3269
# 5   5                       3402
# 6   6                       3364
# 7   7                       3540
# 8   8                       3426
# 9   9                       3375
# 10 10                       3316
# 11 11                       3073
# 12 12                       3189

# %%
# Making the markdown file:
file.create("CaseStudy_GunDeaths_2018.Rmd")
# Out:
# [1] TRUE
